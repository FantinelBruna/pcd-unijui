# %% [markdown]
# <a href="https://colab.research.google.com/github/FantinelBruna/pcd-unijui/blob/main/aula08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q beautifulsoup4 requests

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = (
  "https://store.steampowered.com/search/?specials=1&cc=br&l=portuguese"
)

pagina = requests.get(url)
print("Status:", pagina.status_code)
# Out:
# Status: 200

# %%
soup = BeautifulSoup(
  pagina.text,
  "html.parser"
)

# %%
produtos = soup.select(
  "a.search_result_row"
)

# %%
for produto in produtos:
  nome = produto.select_one(
    "span.title"
  ).get_text(strip=True)

  preco_original = produto.select_one(
    ".discount_original_price"
  ).get_text(strip=True)

  preco_promocional = produto.select_one(
    ".discount_final_price"
  ).get_text(strip=True)

  desconto = produto.select_one(
    ".discount_pct"
  ).get_text(strip=True)

  print("Nome:", nome)
  print("Preço original:", preco_original)
  print("Desconto:", desconto)
  print("Preço promocional:", preco_promocional)
  print("-" * 50)
# Out:
# Nome: Dying Light: The Beast
# Preço original: R$249,00
# Desconto: -50%
# Preço promocional: R$124,50
# --------------------------------------------------
# Nome: Rust
# Preço original: R$119,99
# Desconto: -50%
# Preço promocional: R$59,99
# --------------------------------------------------
# Nome: DEATH STRANDING DIRECTOR'S CUT
# Preço original: R$159,00
# Desconto: -75%
# Preço promocional: R$39,75
# --------------------------------------------------
# Nome: Detroit: Become Human
# Preço original: R$199,99
# Desconto: -80%
# Preço promocional: R$39,99
# --------------------------------------------------
# Nome: RV There Yet?
# Preço original: R$26,49
# Desconto: -40%
# Preço promocional: R$15,89
# --------------------------------------------------
# Nome: Supermarket Simulator
# Preço original: R$59,99
# Desconto: -40%
# Preço promocional: R$35,99
# --------------------------------------------------
# Nome: Watch_Dogs™
# Preço original: R$94,99
# Desconto: -90%
# Preço promocional: R$9,49
# --------------------------------------------------
# Nome: Dying Light 2 Stay Human: Reloaded Edition
# Preço original: R$249,00
# Desconto: -80%
# Preço promocional: R$49,80
# --------------------------------------------------
# Nome: Assetto Corsa Competizione
# Preço original: R$159,00
# Desconto: -75%
# Preço promocional: R$39,75
# --------------------------------------------------
# Nome: Gas Station Simulator
# Preço original: R$59,99
# Desconto: -55%
# Preço promocional: R$26,99
# --------------------------------------------------
# Nome: Escape Simulator 2
# Preço original: R$50,00
# Desconto: -30%
# Preço promocional: R$35,00
# --------------------------------------------------
# Nome: Far Cry 3
# Preço original: R$59,99
# Desconto: -75%
# Preço promocional: R$14,99
# --------------------------------------------------
# Nome: The Quarry
# Preço original: R$399,50
# Desconto: -90%
# Preço promocional: R$39,95
# --------------------------------------------------
# Nome: Human Fall Flat
# Preço original: R$37,99
# Desconto: -70%
# Preço promocional: R$11,39
# --------------------------------------------------
# Nome: South Park™: The Fractured But Whole™
# Preço original: R$139,99
# Desconto: -70%
# Preço promocional: R$41,99
# --------------------------------------------------
# Nome: TCG Card Shop Simulator
# Preço original: R$67,99
# Desconto: -15%
# Preço promocional: R$57,79
# --------------------------------------------------
# Nome: Beyond: Two Souls
# Preço original: R$89,99
# Desconto: -90%
# Preço promocional: R$8,99
# --------------------------------------------------
# Nome: Assassin’s Creed® Brotherhood
# Preço original: R$59,99
# Desconto: -75%
# Preço promocional: R$14,99
# --------------------------------------------------
# Nome: Assassin's Creed® Revelations
# Preço original: R$59,99
# Desconto: -70%
# Preço promocional: R$17,99
# --------------------------------------------------
# Nome: Tricky Towers
# Preço original: R$46,99
# Desconto: -60%
# Preço promocional: R$18,79
# --------------------------------------------------
# Nome: Escape Simulator
# Preço original: R$50,00
# Desconto: -50%
# Preço promocional: R$25,00
# --------------------------------------------------
# Nome: Bunker Tidy Up
# Preço original: R$18,99
# Desconto: -20%
# Preço promocional: R$15,19
# --------------------------------------------------
# Nome: Anime Shop Simulator ✨
# Preço original: R$40,00
# Desconto: -15%
# Preço promocional: R$34,00
# --------------------------------------------------
# Nome: Escape Simulator 2: Apocalypse DLC
# Preço original: R$20,49
# Desconto: -10%
# Preço promocional: R$18,44
# --------------------------------------------------
# Nome: Dying Light 2: Stay Human Digital Extras Edition
# Preço original: R$290,00
# Desconto: -80%
# Preço promocional: R$58,00
# --------------------------------------------------
# Nome: Nioh 2 – The Complete Edition
# Preço original: R$249,00
# Desconto: -60%
# Preço promocional: R$99,60
# --------------------------------------------------
# Nome: Nioh: Complete Edition
# Preço original: R$249,00
# Desconto: -85%
# Preço promocional: R$37,35
# --------------------------------------------------
# Nome: The Sims™ 2 Legacy Collection
# Preço original: R$129,00
# Desconto: -50%
# Preço promocional: R$64,50
# --------------------------------------------------
# Nome: Heavy Rain
# Preço original: R$89,99
# Desconto: -90%
# Preço promocional: R$8,99
# --------------------------------------------------
# Nome: Scorn
# Preço original: R$75,99
# Desconto: -90%
# Preço promocional: R$7,59
# --------------------------------------------------
# Nome: Titanfall® 2
# Preço original: R$89,00
# Desconto: -85%
# Preço promocional: R$13,35
# --------------------------------------------------
# Nome: Returns Outlet Simulator
# Preço original: R$32,99
# Desconto: -30%
# Preço promocional: R$23,09
# --------------------------------------------------
# Nome: Car Dealer Simulator
# Preço original: R$61,25
# Desconto: -30%
# Preço promocional: R$42,87
# --------------------------------------------------
# Nome: Police Chief Simulator
# Preço original: R$61,25
# Desconto: -10%
# Preço promocional: R$55,12
# --------------------------------------------------
# Nome: Ancestors: The Humankind Odyssey
# Preço original: R$119,99
# Desconto: -75%
# Preço promocional: R$29,99
# --------------------------------------------------
# Nome: Minibus Simulator
# Preço original: R$53,49
# Desconto: -10%
# Preço promocional: R$48,14
# --------------------------------------------------
# Nome: HAELE 3D - Estúdio de Retrato Pro - Referências de Desenho
# Preço original: R$99,99
# Desconto: -15%
# Preço promocional: R$84,99
# --------------------------------------------------
# Nome: Assetto Corsa Competizione - 24H Nürburgring Pack
# Preço original: R$39,99
# Desconto: -50%
# Preço promocional: R$19,99
# --------------------------------------------------
# Nome: Paver: Tidy Up Together
# Preço original: R$19,49
# Desconto: -10%
# Preço promocional: R$17,54
# --------------------------------------------------
# Nome: Surgeon Simulator 2
# Preço original: R$59,99
# Desconto: -85%
# Preço promocional: R$8,99
# --------------------------------------------------
# Nome: Assetto Corsa Competizione - American Track Pack
# Preço original: R$69,99
# Desconto: -60%
# Preço promocional: R$27,99
# --------------------------------------------------
# Nome: DUSK
# Preço original: R$49,99
# Desconto: -60%
# Preço promocional: R$19,99
# --------------------------------------------------
# Nome: Dinoblade
# Preço original: R$67,99
# Desconto: -10%
# Preço promocional: R$61,19
# --------------------------------------------------
# Nome: The Loopler
# Preço original: R$29,99
# Desconto: -10%
# Preço promocional: R$26,99
# --------------------------------------------------
# Nome: Necrophosis
# Preço original: R$49,99
# Desconto: -55%
# Preço promocional: R$22,49
# --------------------------------------------------
# Nome: Far Cry 3 - Blood Dragon
# Preço original: R$44,99
# Desconto: -75%
# Preço promocional: R$11,24
# --------------------------------------------------
# Nome: Friends vs Friends
# Preço original: R$32,99
# Desconto: -75%
# Preço promocional: R$8,24
# --------------------------------------------------
# Nome: Age of History II
# Preço original: R$22,49
# Desconto: -85%
# Preço promocional: R$3,37
# --------------------------------------------------
# Nome: Assetto Corsa Competizione - GT4 Pack
# Preço original: R$79,60
# Desconto: -60%
# Preço promocional: R$31,84
# --------------------------------------------------
# Nome: Besiege
# Preço original: R$41,99
# Desconto: -80%
# Preço promocional: R$8,39
# --------------------------------------------------

# %% [markdown]
# ------------------------------------

# %%
html_doc = """
<html><head><title>A história do Dormundongo</title></head>
<body>
<p class="title"><b>A história do Dormundongo</b></p>

<p class="story">Era uma vez três irmãs pequenas; e seus nomes eram
<a href="http://example.com/elsie&quot; class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie&quot; class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie&quot; class="sister" id="link3">Tillie</a>;
E eles viviam no fundo de um poço.</p>

<p class="story">...</p>
"""

from bs4 import BeautifulSoup
soup = BeautifulSoup(html_doc, 'html.parser')
# ---------

soup.title
# <title>The Dormouse's story</title>

# ---------
soup.title.name
# u'title'

# ---------
soup.title.string
# 'A história do Dormundongo'

# ---------
soup.title.parent.name
# u'head'

# ---------
soup.p
# <p class="title"><b>A história do Dormundongo</b></p>

# ---------
soup.p['class']
# u'title'

# ---------
soup.a
# <a class="sister" href="http://example.com/elsie&quot; id="link1">Elsie</a>
# ---------

soup.find_all('a')
# [<a class="sister" href="http://example.com/elsie&quot; id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie&quot; id="link2">Lacie</a>,
# <a class="sister" href="http://example.com/tillie&quot; id="link3">Tillie</a>]
# ---------

soup.find(id="link3")
# <a class="sister" href="http://example.com/tillie&quot; id="link3">Tillie</a>
# Out:
# <a href='http://example.com/tillie" class=' id="link3" sister"="">Tillie</a>

# %% [markdown]
# ------------------------------------

# %%
# !pip install -q google-colab-selenium
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 78.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.8/511.8 kB 32.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.7/135.7 kB 10.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 84.2 MB/s eta 0:00:00

# %%
import google_colab_selenium as gs
from selenium.webdriver.common.by import By
from time import sleep

# %%
navegador = gs.Chrome()
# Out:
#             <div class="spinner-container">
#                 <div class="spinner" id="748519a9-a215-4365-b12e-361d991e163d-circle"></div>
#                 <div class="spinner-text" id="748519a9-a215-4365-b12e-361d991e163d-text">Preparing environment</div>
#             </div>
#             <style>
#                 @keyframes spin {
#                     from { transform: rotate(0deg); }
#                     to { transform: rotate(360deg); }
#                 }
#
#                 .spinner-container {
#                     display: flex;
#                     align-items: center;
#                     margin-bottom: 3px;
#                 }
#
#                 .spinner {
#                     border: 3px solid rgba(0, 0, 0, 0.1);
#                     border-left-color: lightblue;
#                     border-radius: 50%;
#                     width: 12px;
#                     height: 12px;
#                     animation: spin 1s linear infinite;
#                 }
#
#                 .spinner-text {
#                     padding-left: 6px;
#                 }
#             </style>
#             <div class="spinner-container">
#                 <div class="spinner" id="12fb760a-1774-4d99-ae82-c557750a4538-circle"></div>
#                 <div class="spinner-text" id="12fb760a-1774-4d99-ae82-c557750a4538-text">Downloading Google Chrome</div>
#             </div>
#             <style>
#                 @keyframes spin {
#                     from { transform: rotate(0deg); }
#                     to { transform: rotate(360deg); }
#                 }
#
#                 .spinner-container {
#                     display: flex;
#                     align-items: center;
#                     margin-bottom: 3px;
#                 }
#
#                 .spinner {
#                     border: 3px solid rgba(0, 0, 0, 0.1);
#                     border-left-color: lightblue;
#                     border-radius: 50%;
#                     width: 12px;
#                     height: 12px;
#                     animation: spin 1s linear infinite;
#                 }
#
#                 .spinner-text {
#                     padding-left: 6px;
#                 }
#             </style>
#             <div class="spinner-container">
#                 <div class="spinner" id="12714f0e-ba6c-469d-97cc-4f969659b127-circle"></div>
#                 <div class="spinner-text" id="12714f0e-ba6c-469d-97cc-4f969659b127-text">Initializing Chromedriver</div>
#             </div>
#             <style>
#                 @keyframes spin {
#                     from { transform: rotate(0deg); }
#                     to { transform: rotate(360deg); }
#                 }
#
#                 .spinner-container {
#                     display: flex;
#                     align-items: center;
#                     margin-bottom: 3px;
#                 }
#
#                 .spinner {
#                     border: 3px solid rgba(0, 0, 0, 0.1);
#                     border-left-color: lightblue;
#                     border-radius: 50%;
#                     width: 12px;
#                     height: 12px;
#                     animation: spin 1s linear infinite;
#                 }
#
#                 .spinner-text {
#                     padding-left: 6px;
#                 }
#             </style>

# %%
url = (
  "https://www.ecb.europa.eu/stats/policy_and_exchange_rates/euro_reference_exchange_rates/html/index.en.html"
)

# %%
navegador.get(url)
sleep(2)
print("Página:", navegador.title)
# Out:
# Página: Euro foreign exchange reference rates

# %%
botoes = navegador.find_elements(
  By.XPATH,
  "//*[@id='cookieConsent']//button"
  "[contains(., 'I do not accept')]"
)

# %%
for botao in botoes:
  if botao.is_displayed():
    navegador.execute_script(
      "arguments[0].click();", botao
    )
    break
sleep(1)

# %%
dolar = navegador.find_element(
  By.XPATH,
  "//tr[td[normalize-space()='USD']]/td[3]"
).text

# %%
real = navegador.find_element(
  By.XPATH,
  "//tr[td[normalize-space()='BRL']]/td[3]"
).text

# %%
# Exibindo as cotações
print("\nCOTAÇÕES:")
print("1 EUR =", dolar, "USD")
print("1 EUR =", real, "BRL")
# Conversão dólar -> real
dolar_real = float(real) / float(dolar)
print("1 USD =", round(dolar_real, 2), "BRL")
# Out:
# COTAÇÕES:
# 1 EUR = 1.1411 USD
# 1 EUR = 5.8564 BRL
# 1 USD = 5.13 BRL
